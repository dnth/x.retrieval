# %%
import xretrieval

metrics, results_df = xretrieval.run_benchmark(
    dataset="coco-val-2017",
    model_id="transformers/Salesforce/blip2-itm-vit-g",
    mode="text-to-text",
)
# Out:
# 2024-11-20 13:06:26.850 | INFO     | xretrieval.datasets.coco:__init__:26 - COCO validation dataset found in data/coco/val2017, skipping download
# 2024-11-20 13:06:32.792 | INFO     | xretrieval.core:run_benchmark:104 - Encoding database text for transformers/Salesforce/blip2-itm-vit-g
# Encoding captions:   0%|          | 0/157 [00:00<?, ?it/s]
# Expanding inputs for image tokens in BLIP-2 should be done in processing. Please follow instruction here (https://gist.github.com/zucchini-nlp/e9f20b054fa322f84ac9311d9ab67042) to update your BLIP-2 model. Using processors without these attributes in the config is deprecated and will throw an error in v4.47.
# 2024-11-20 13:06:35.305 | INFO     | xretrieval.core:run_benchmark:112 - Encoding query text for transformers/Salesforce/blip2-itm-vit-g
# Encoding captions:   0%|          | 0/157 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]

# %%
results_df
# Out:
#       query_id                          query_path  \
# 0          139  data/coco/val2017/000000000139.jpg
# 1          285  data/coco/val2017/000000000285.jpg
# 2          632  data/coco/val2017/000000000632.jpg
# 3          724  data/coco/val2017/000000000724.jpg
# 4          776  data/coco/val2017/000000000776.jpg
# ...        ...                                 ...
# 4995    581317  data/coco/val2017/000000581317.jpg
# 4996    581357  data/coco/val2017/000000581357.jpg
# 4997    581482  data/coco/val2017/000000581482.jpg
# 4998    581615  data/coco/val2017/000000581615.jpg
# 4999    581781  data/coco/val2017/000000581781.jpg
#
#                                           query_caption  \
# 0     A woman stands in the dining area at the table...
# 1     A big burly grizzly bear is show with grass in...
# 2     Bedroom scene with a bookcase, blue comforter ...
# 3     A stop sign is mounted upside-down on it's pos...
# 4     Three teddy bears, each a different color, snu...
# ...                                                 ...
# 4995  A woman holding a small item in a field. Woman...
# 4996  Skate boarder hang time with young man appeari...
# 4997  A fancy metal cloth is seen against huge barre...
# 4998  A picture of a white toilet in the rest room. ...
# 4999  A store display filled with ripe, unripe banan...
#
#                                              query_name  \
# 0     book,chair,clock,dining table,microwave,person...
# 1                                                  bear
# 2                           bed,book,chair,potted plant
# 3                                   car,stop sign,truck
# 4                                        bed,teddy bear
# ...                                                 ...
# 4995                                  cell phone,person
# 4996                            bench,person,skateboard
# 4997                                              clock
# 4998                                             toilet
# 4999                                             banana
#
#                                           retrieved_ids  \
# 0     [441247, 154358, 492758, 435208, 369503, 40448...
# 1     [132622, 307658, 110972, 471450, 312586, 53207...
# 2     [403353, 183049, 65074, 134882, 294783, 464358...
# 3     [484029, 309173, 191471, 213593, 336587, 12659...
# 4     [113403, 383386, 50844, 73118, 226058, 478393,...
# ...                                                 ...
# 4995  [203639, 459272, 261061, 161875, 346968, 43398...
# 4996  [450559, 362520, 451084, 377635, 438907, 12547...
# 4997  [106563, 67896, 331317, 140929, 76211, 151857,...
# 4998  [201775, 348045, 206271, 234413, 175387, 34821...
# 4999  [560256, 50149, 479596, 509131, 371472, 407574...
#
#                                         retrieved_paths  \
# 0     [data/coco/val2017/000000441247.jpg, data/coco...
# 1     [data/coco/val2017/000000132622.jpg, data/coco...
# 2     [data/coco/val2017/000000403353.jpg, data/coco...
# 3     [data/coco/val2017/000000484029.jpg, data/coco...
# 4     [data/coco/val2017/000000113403.jpg, data/coco...
# ...                                                 ...
# 4995  [data/coco/val2017/000000203639.jpg, data/coco...
# 4996  [data/coco/val2017/000000450559.jpg, data/coco...
# 4997  [data/coco/val2017/000000106563.jpg, data/coco...
# 4998  [data/coco/val2017/000000201775.jpg, data/coco...
# 4999  [data/coco/val2017/000000560256.jpg, data/coco...
#
#                                      retrieved_captions  \
# 0     [A woman standing in a kitchen next to a table...
# 1     [The large bear is looking in the direction of...
# 2     [A lamp sitting next to a small bed with a boo...
# 3     [A stop sign with a street sign above it. A st...
# 4     [Three teddy bears laying in bed under the cov...
# ...                                                 ...
# 4995  [A girl in a dress and shirt standing in a fie...
# 4996  [A teenager doing skateboard tricks at a skate...
# 4997  [A clock that is hanging underneath a glass ar...
# 4998  [A bathroom with two urinals and a sink. White...
# 4999  [A market area with boxes of fruit that includ...
#
#                                         retrieved_names  \
# 0     [backpack,banana,bottle,chair,clock,couch,dini...
# 1     [bear, bear, bear, bear, bear, bear, bear, bea...
# 2     [bed,book, book,clock, bed,book, bed,book,cat,...
# 3     [car,stop sign, person,stop sign, stop sign, c...
# 4     [bed,teddy bear, chair,teddy bear, teddy bear,...
# ...                                                 ...
# 4995  [person,tie, cell phone,person, baseball bat,p...
# 4996  [person,skateboard, person,skateboard, person,...
# 4997  [clock, clock, clock,person, clock, clock, tra...
# 4998  [sink,toilet, toilet, toilet, toilet, toilet, ...
# 4999  [apple,banana,orange, banana,bowl, apple,orang...
#
#                                              is_correct
# 0     [False, False, False, False, False, False, Fal...
# 1     [True, True, True, True, True, True, True, Tru...
# 2     [False, False, False, False, False, False, Fal...
# 3     [False, False, False, False, False, False, Fal...
# 4     [True, False, False, False, False, False, Fals...
# ...                                                 ...
# 4995  [False, True, False, False, False, True, False...
# 4996  [False, False, False, False, False, False, Fal...
# 4997  [True, True, False, True, True, False, False, ...
# 4998  [False, True, True, True, True, True, True, Tr...
# 4999  [False, False, False, False, True, True, False...
#
# [5000 rows x 9 columns]

# %%
import xretrieval

metrics, results_df = xretrieval.run_benchmark(
    dataset="coco-val-2017",
    model_id="transformers/Salesforce/blip2-itm-vit-g",
    mode="text-to-image",
)
# Out:
# 2024-11-20 13:07:45.384 | INFO     | xretrieval.datasets.coco:__init__:26 - COCO validation dataset found in data/coco/val2017, skipping download
# 2024-11-20 13:07:50.402 | INFO     | xretrieval.core:run_benchmark:101 - Encoding database images for transformers/Salesforce/blip2-itm-vit-g
# Encoding images:   0%|          | 0/157 [00:00<?, ?it/s]
# 2024-11-20 13:09:10.484 | INFO     | xretrieval.core:run_benchmark:112 - Encoding query text for transformers/Salesforce/blip2-itm-vit-g
# Encoding captions:   0%|          | 0/157 [00:00<?, ?it/s]

# %%
metrics
# Out:
# {'MRR': 0.3205,
#  'NormalizedDCG': 0.5122,
#  'Precision': 0.2312,
#  'Recall': 0.8854,
#  'HitRate': 0.8854,
#  'MAP': 0.2918}

# %%
results_df
# Out:
#       query_id                          query_path  \
# 0          139  data/coco/val2017/000000000139.jpg
# 1          285  data/coco/val2017/000000000285.jpg
# 2          632  data/coco/val2017/000000000632.jpg
# 3          724  data/coco/val2017/000000000724.jpg
# 4          776  data/coco/val2017/000000000776.jpg
# ...        ...                                 ...
# 4995    581317  data/coco/val2017/000000581317.jpg
# 4996    581357  data/coco/val2017/000000581357.jpg
# 4997    581482  data/coco/val2017/000000581482.jpg
# 4998    581615  data/coco/val2017/000000581615.jpg
# 4999    581781  data/coco/val2017/000000581781.jpg
#
#                                           query_caption  \
# 0     A woman stands in the dining area at the table...
# 1     A big burly grizzly bear is show with grass in...
# 2     Bedroom scene with a bookcase, blue comforter ...
# 3     A stop sign is mounted upside-down on it's pos...
# 4     Three teddy bears, each a different color, snu...
# ...                                                 ...
# 4995  A woman holding a small item in a field. Woman...
# 4996  Skate boarder hang time with young man appeari...
# 4997  A fancy metal cloth is seen against huge barre...
# 4998  A picture of a white toilet in the rest room. ...
# 4999  A store display filled with ripe, unripe banan...
#
#                                              query_name  \
# 0     book,chair,clock,dining table,microwave,person...
# 1                                                  bear
# 2                           bed,book,chair,potted plant
# 3                                   car,stop sign,truck
# 4                                        bed,teddy bear
# ...                                                 ...
# 4995                                  cell phone,person
# 4996                            bench,person,skateboard
# 4997                                              clock
# 4998                                             toilet
# 4999                                             banana
#
#                                           retrieved_ids  \
# 0     [435208, 492758, 441247, 396526, 139, 107339, ...
# 1     [513484, 132622, 471869, 453981, 229997, 23937...
# 2     [632, 464358, 51738, 134882, 294783, 10995, 18...
# 3     [172856, 104782, 193884, 239843, 579893, 19271...
# 4     [383386, 211120, 174018, 349480, 335081, 776, ...
# ...                                                 ...
# 4995  [581317, 161875, 1268, 42528, 295713, 39914, 3...
# 4996  [538458, 424521, 176799, 378673, 256868, 28886...
# 4997  [581482, 312263, 106563, 430048, 355169, 33131...
# 4998  [564023, 581615, 365387, 155154, 348045, 85576...
# 4999  [356428, 581781, 371472, 125936, 378515, 40757...
#
#                                         retrieved_paths  \
# 0     [data/coco/val2017/000000435208.jpg, data/coco...
# 1     [data/coco/val2017/000000513484.jpg, data/coco...
# 2     [data/coco/val2017/000000000632.jpg, data/coco...
# 3     [data/coco/val2017/000000172856.jpg, data/coco...
# 4     [data/coco/val2017/000000383386.jpg, data/coco...
# ...                                                 ...
# 4995  [data/coco/val2017/000000581317.jpg, data/coco...
# 4996  [data/coco/val2017/000000538458.jpg, data/coco...
# 4997  [data/coco/val2017/000000581482.jpg, data/coco...
# 4998  [data/coco/val2017/000000564023.jpg, data/coco...
# 4999  [data/coco/val2017/000000356428.jpg, data/coco...
#
#                                      retrieved_captions  \
# 0     [A young woman sitting cross legged on an apar...
# 1     [A large brown bear standing next to a pile of...
# 2     [Bedroom scene with a bookcase, blue comforter...
# 3     [a stop sign and two brown and white street si...
# 4     [a couple of stuffed bears are on a bed Stuffe...
# ...                                                 ...
# 4995  [A woman holding a small item in a field. Woma...
# 4996  [THERE ARE PEOPLE PLAYING SKATE BOARD ON THE S...
# 4997  [A fancy metal cloth is seen against huge barr...
# 4998  [A public restroom with a toilet in the floor....
# 4999  [A couple of people walking through a market f...
#
#                                         retrieved_names  \
# 0     [chair,clock,couch,cup,dining table,keyboard,l...
# 1     [bear, bear, couch,teddy bear,tie, bear, bear,...
# 2     [bed,book,chair,potted plant, bed,chair,tv, be...
# 3     [stop sign, stop sign, stop sign, stop sign, s...
# 4     [chair,teddy bear, bowl,teddy bear,truck, tedd...
# ...                                                 ...
# 4995  [cell phone,person, person,tie, backpack,bird,...
# 4996  [person,skateboard,traffic light,truck, person...
# 4997  [clock, clock, clock, car,clock, clock, clock,...
# 4998  [toilet, toilet, bed,cup,sink,toilet, toilet, ...
# 4999  [backpack,banana,person, banana, banana, apple...
#
#                                              is_correct
# 0     [False, False, False, False, True, False, Fals...
# 1     [True, True, False, True, False, False, False,...
# 2     [True, False, False, False, False, False, Fals...
# 3     [False, False, False, False, False, False, Fal...
# 4     [False, False, False, False, False, True, True...
# ...                                                 ...
# 4995  [True, False, False, False, False, False, Fals...
# 4996  [False, False, False, False, True, False, Fals...
# 4997  [True, True, True, False, True, False, True, T...
# 4998  [True, True, False, True, True, True, False, T...
# 4999  [False, True, True, False, False, True, False,...
#
# [5000 rows x 9 columns]
