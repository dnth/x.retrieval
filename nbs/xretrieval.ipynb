# %%
import xretrieval

xretrieval.list_datasets()
# Out:
# ['coco-val-2017']

# %%
dataset = xretrieval.load_dataset("coco-val-2017")

# %%
dataset
# Out:
#       image_id         file_name  \
# 0          139  000000000139.jpg
# 1          285  000000000285.jpg
# 2          632  000000000632.jpg
# 3          724  000000000724.jpg
# 4          776  000000000776.jpg
# ...        ...               ...
# 4995    581317  000000581317.jpg
# 4996    581357  000000581357.jpg
# 4997    581482  000000581482.jpg
# 4998    581615  000000581615.jpg
# 4999    581781  000000581781.jpg
#
#                                              image_path  \
# 0     /home/dnth/Desktop/automatic-retrieval-benchma...
# 1     /home/dnth/Desktop/automatic-retrieval-benchma...
# 2     /home/dnth/Desktop/automatic-retrieval-benchma...
# 3     /home/dnth/Desktop/automatic-retrieval-benchma...
# 4     /home/dnth/Desktop/automatic-retrieval-benchma...
# ...                                                 ...
# 4995  /home/dnth/Desktop/automatic-retrieval-benchma...
# 4996  /home/dnth/Desktop/automatic-retrieval-benchma...
# ...
