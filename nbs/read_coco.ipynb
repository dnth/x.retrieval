# %%
from xretrieval.datasets.coco import COCODataset

# %%
dataset = COCODataset("../data/coco")
dataset.load_annotations()
# Out:
#               file_name  image_id  \
# 0      000000397133.jpg    397133
# 1      000000397133.jpg    397133
# 2      000000397133.jpg    397133
# 3      000000397133.jpg    397133
# 4      000000397133.jpg    397133
# ...                 ...       ...
# 25009  000000015335.jpg     15335
# 25010  000000015335.jpg     15335
# 25011  000000015335.jpg     15335
# 25012  000000015335.jpg     15335
# 25013  000000015335.jpg     15335
#
#                                                  caption  \
# 0                   A man is in a kitchen making pizzas.
# 1      Man in apron standing on front of oven with pa...
# 2       A baker is working in the kitchen rolling dough.
# 3             A person standing by a stove in a kitchen.
# 4      A table with pies being made and a person stan...
# ...                                                  ...
# 25009    A group of people sitting at a table with food.
# 25010      A man, woman, and boy are sitting at a table.
# ...

# %%
dataset.get_dataset()
# Out:
#       image_id         file_name                             image_path  \
# 0          139  000000000139.jpg  ../data/coco/val2017/000000000139.jpg
# 1          285  000000000285.jpg  ../data/coco/val2017/000000000285.jpg
# 2          632  000000000632.jpg  ../data/coco/val2017/000000000632.jpg
# 3          724  000000000724.jpg  ../data/coco/val2017/000000000724.jpg
# 4          776  000000000776.jpg  ../data/coco/val2017/000000000776.jpg
# ...        ...               ...                                    ...
# 4995    581317  000000581317.jpg  ../data/coco/val2017/000000581317.jpg
# 4996    581357  000000581357.jpg  ../data/coco/val2017/000000581357.jpg
# 4997    581482  000000581482.jpg  ../data/coco/val2017/000000581482.jpg
# 4998    581615  000000581615.jpg  ../data/coco/val2017/000000581615.jpg
# 4999    581781  000000581781.jpg  ../data/coco/val2017/000000581781.jpg
#
#                                                 caption
# ...
