# %%
# !pip install xretrieval==0.1.0
# Out:
# Collecting xretrieval==0.1.0
#   Downloading xretrieval-0.1.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: accelerate>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from xretrieval==0.1.0) (1.1.1)
# Collecting faiss-cpu>=1.9.0 (from xretrieval==0.1.0)
#   Downloading faiss_cpu-1.9.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Collecting loguru>=0.7.0 (from xretrieval==0.1.0)
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Collecting matplotlib>=3.9.0 (from xretrieval==0.1.0)
#   Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from xretrieval==0.1.0) (2.2.2)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from xretrieval==0.1.0) (11.0.0)
# Requirement already satisfied: rich>=13.9.0 in /usr/local/lib/python3.10/dist-packages (from xretrieval==0.1.0) (13.9.4)
# Collecting sentence-transformers>=3.3.0 (from xretrieval==0.1.0)
#   Downloading sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: timm>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from xretrieval==0.1.0) (1.0.11)
# Collecting torchmetrics>=1.6.0 (from xretrieval==0.1.0)
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Collecting tqdm>=4.67.0 (from xretrieval==0.1.0)
#   Downloading tqdm-4.67.0-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: transformers>=4.46.0 in /usr/local/lib/python3.10/dist-packages (from xretrieval==0.1.0) (4.46.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=1.1.0->xretrieval==0.1.0) (0.26.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=1.1.0->xretrieval==0.1.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=1.1.0->xretrieval==0.1.0) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=1.1.0->xretrieval==0.1.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=1.1.0->xretrieval==0.1.0) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=1.1.0->xretrieval==0.1.0) (0.4.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=1.1.0->xretrieval==0.1.0) (2.5.1+cu121)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.9.0->xretrieval==0.1.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.9.0->xretrieval==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.9.0->xretrieval==0.1.0) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.9.0->xretrieval==0.1.0) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.9.0->xretrieval==0.1.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.9.0->xretrieval==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.0->xretrieval==0.1.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.0->xretrieval==0.1.0) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.9.0->xretrieval==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.9.0->xretrieval==0.1.0) (2.18.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.9.0->xretrieval==0.1.0) (4.12.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=3.3.0->xretrieval==0.1.0) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=3.3.0->xretrieval==0.1.0) (1.13.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm>=1.0.0->xretrieval==0.1.0) (0.20.1+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics>=1.6.0->xretrieval==0.1.0)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.0->xretrieval==0.1.0) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.0->xretrieval==0.1.0) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.0->xretrieval==0.1.0) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.0->xretrieval==0.1.0) (0.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate>=1.1.0->xretrieval==0.1.0) (2024.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics>=1.6.0->xretrieval==0.1.0) (75.1.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.0->xretrieval==0.1.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9.0->xretrieval==0.1.0) (1.16.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=1.1.0->xretrieval==0.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=1.1.0->xretrieval==0.1.0) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate>=1.1.0->xretrieval==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate>=1.1.0->xretrieval==0.1.0) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.46.0->xretrieval==0.1.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.46.0->xretrieval==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.46.0->xretrieval==0.1.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.46.0->xretrieval==0.1.0) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=3.3.0->xretrieval==0.1.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=3.3.0->xretrieval==0.1.0) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate>=1.1.0->xretrieval==0.1.0) (3.0.2)
# Downloading xretrieval-0.1.0-py3-none-any.whl (11 kB)
# Downloading faiss_cpu-1.9.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 56.9 MB/s eta 0:00:00
# Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 4.7 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 71.5 MB/s eta 0:00:00
# Downloading sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 11.1 MB/s eta 0:00:00
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 44.9 MB/s eta 0:00:00
# Downloading tqdm-4.67.0-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.1 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Installing collected packages: tqdm, loguru, lightning-utilities, faiss-cpu, matplotlib, torchmetrics, sentence-transformers, xretrieval
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.6
#     Uninstalling tqdm-4.66.6:
#       Successfully uninstalled tqdm-4.66.6
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.0
#     Uninstalling matplotlib-3.8.0:
#       Successfully uninstalled matplotlib-3.8.0
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.2.1
#     Uninstalling sentence-transformers-3.2.1:
#       Successfully uninstalled sentence-transformers-3.2.1
# Successfully installed faiss-cpu-1.9.0.post1 lightning-utilities-0.11.9 loguru-0.7.2 matplotlib-3.9.2 sentence-transformers-3.3.1 torchmetrics-1.6.0 tqdm-4.67.0 xretrieval-0.1.0

# %%
import xretrieval

xretrieval.list_models()
# Out:
#                          Available Models
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Model ID                                         ┃ Model Input ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ transformers/Salesforce/blip2-itm-vit-g          │ text-image  │
# │ transformers/Salesforce/blip2-itm-vit-g-text     │ text        │
# │ transformers/Salesforce/blip2-itm-vit-g-image    │ image       │
# │ sentence-transformers/paraphrase-MiniLM-L3-v2    │ text        │
# │ sentence-transformers/paraphrase-albert-small-v2 │ text        │
# │ sentence-transformers/multi-qa-distilbert-cos-v1 │ text        │
# │ sentence-transformers/all-MiniLM-L12-v2          │ text        │
# │ sentence-transformers/all-distilroberta-v1       │ text        │
# │ sentence-transformers/multi-qa-mpnet-base-dot-v1 │ text        │
# │ sentence-transformers/all-mpnet-base-v2          │ text        │
# │ sentence-transformers/multi-qa-MiniLM-L6-cos-v1  │ text        │
# │ sentence-transformers/all-MiniLM-L6-v2           │ text        │
# │ timm/resnet18.a1_in1k                            │ image       │
# └──────────────────────────────────────────────────┴─────────────┘

# %%
xretrieval.run_benchmark(
    dataset_name="coco-val-2017",
    model_id="sentence-transformers/all-MiniLM-L6-v2",
    mode="text-to-text",
)
# Out:
# 2024-11-20 03:08:35.068 | INFO     | xretrieval.datasets.coco:__init__:22 - COCO validation dataset not found in data/coco/val2017
# 2024-11-20 03:08:35.070 | INFO     | xretrieval.datasets.coco:__init__:23 - Downloading COCO validation dataset...
# 2024-11-20 03:08:35.073 | INFO     | xretrieval.datasets.coco:download:66 - Downloading COCO validation dataset...
# Downloading val2017.zip: 100%|██████████| 778M/778M [00:19<00:00, 42.1MiB/s]
# 2024-11-20 03:08:54.650 | INFO     | xretrieval.datasets.coco:download:71 - Extracting images...
# 2024-11-20 03:08:59.536 | INFO     | xretrieval.datasets.coco:download:77 - Downloading COCO annotations...
# Downloading annotations_trainval2017.zip: 100%|██████████| 241M/241M [00:05<00:00, 47.1MiB/s]
# 2024-11-20 03:09:05.113 | INFO     | xretrieval.datasets.coco:download:83 - Extracting annotations...
# 2024-11-20 03:09:11.335 | INFO     | xretrieval.datasets.coco:download:88 - Download and extraction complete!
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 2024-11-20 03:09:18.436 | INFO     | xretrieval.core:run_benchmark:84 - Encoding database text for sentence-transformers/all-MiniLM-L6-v2
# 2024-11-20 03:09:23.748 | INFO     | xretrieval.core:run_benchmark:92 - Encoding query text for sentence-transformers/all-MiniLM-L6-v2
#   0%|          | 0/5000 [00:00<?, ?it/s]
# {'MRR': 0.2972,
#  'NormalizedDCG': 0.3442,
#  'Precision': 0.2248,
#  'Recall': 0.4772,
#  'HitRate': 0.4772,
#  'MAP': 0.273}

# %%
xretrieval.visualize_retrieval(
    dataset_name="coco-val-2017",
    model_id="sentence-transformers/all-MiniLM-L6-v2",
    mode="text-to-text",
)
# Out:
# 2024-11-20 03:09:29.955 | INFO     | xretrieval.datasets.coco:__init__:26 - COCO validation dataset found in data/coco/val2017, skipping download
# /usr/local/lib/python3.10/dist-packages/xretrieval/core.py:242: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()
